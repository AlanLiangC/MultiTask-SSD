# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
idx = '000226'
img = plt.imread(f'./{idx}/{idx}_img.png')
gt_img = plt.imread(f'./{idx}/{idx}_gt.png')
pred_img = plt.imread(f'./{idx}/{idx}_pred.png')

# %%
img = (img*255).astype(np.uint8)

# %%
plt.imshow(img)

# %%
gt_img.min()
# Out:
# 0

# %%
from PIL import Image
import numpy as np
spect= Image.open(f'./{idx}/{idx}_pred.png')
spect.show()
# Out:
# (eog:604741): EOG-WARNING **: 13:34:14.903: Couldn't load icon: Icon 'image-loading' not present in theme Yaru

# %%
import cv2
import numpy as np
img = cv2.imread(f'./{idx}/{idx}_gt.png')    # 加载图片
cv2.namedWindow("cs")                                           # 创建一个窗口，名称cs
cv2.imshow("cs",img)                                            # 在窗口cs中显示图片
cv2.waitKey(2000)
cv2.destroyAllWindows()                                         # 释放窗口
